# %%
import pandas as pd
import qgrid
import matplotlib as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel('economic_freedom_index2019_data.xlsx')

# %%
data
# Out:
#      CountryID   Country Name                        Region  World Rank  \
# 0           97  Liechtenstein                        Europe         NaN
# 1           77           Iraq  Middle East and North Africa         NaN
# 2          181          Yemen  Middle East and North Africa         NaN
# 3          159          Syria  Middle East and North Africa         NaN
# 4          184        Somalia            Sub-Saharan Africa         NaN
# ..         ...            ...                           ...         ...
# 181          7      Australia                  Asia-Pacific         5.0
# 182        158    Switzerland                        Europe         4.0
# 183        120    New Zealand                  Asia-Pacific         3.0
# 184        147      Singapore                  Asia-Pacific         2.0
# 185         71      Hong Kong                  Asia-Pacific         1.0
#
#      Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# ...

# %%
data.info()
# # # data.shape
# data.keys()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 29 columns):
# CountryID                      186 non-null int64
# Country Name                   186 non-null object
# Region                         186 non-null object
# World Rank                     180 non-null float64
# Region Rank                    180 non-null float64
# 2019 Score                     180 non-null float64
# Property Rights                185 non-null float64
# Judical Effectiveness          185 non-null float64
# Government Integrity           185 non-null float64
# Tax Burden                     180 non-null float64
# Gov't Spending                 183 non-null float64
# Fiscal Health                  183 non-null float64
# Business Freedom               185 non-null float64
# Labor Freedom                  184 non-null float64
# Monetary Freedom               184 non-null float64
# Trade Freedom                  182 non-null float64
# ...

# %%
data.fillna(0, inplace=True)

# %%
data
# Out:
#      CountryID   Country Name                        Region  World Rank  \
# 0           97  Liechtenstein                        Europe         0.0
# 1           77           Iraq  Middle East and North Africa         0.0
# 2          181          Yemen  Middle East and North Africa         0.0
# 3          159          Syria  Middle East and North Africa         0.0
# 4          184        Somalia            Sub-Saharan Africa         0.0
# ..         ...            ...                           ...         ...
# 181          7      Australia                  Asia-Pacific         5.0
# 182        158    Switzerland                        Europe         4.0
# 183        120    New Zealand                  Asia-Pacific         3.0
# 184        147      Singapore                  Asia-Pacific         2.0
# 185         71      Hong Kong                  Asia-Pacific         1.0
#
#      Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# ...

# %%
data['GDP (Billions PPP)'].astype('float32')
# GDP per Capita (PPP)
# Out:
# 0         6.100000
# 1       658.799988
# 2        38.599998
# 3         0.000000
# 4        18.700001
#           ...
# 181    1246.500000
# 182     517.200012
# 183     188.600006
# 184     527.000000
# 185     454.899994
# Name: GDP (Billions PPP), Length: 186, dtype: float32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 29 columns):
# CountryID                      186 non-null int64
# Country Name                   186 non-null object
# Region                         186 non-null object
# World Rank                     186 non-null float64
# Region Rank                    186 non-null float64
# 2019 Score                     186 non-null float64
# Property Rights                186 non-null float64
# Judical Effectiveness          186 non-null float64
# Government Integrity           186 non-null float64
# Tax Burden                     186 non-null float64
# Gov't Spending                 186 non-null float64
# Fiscal Health                  186 non-null float64
# Business Freedom               186 non-null float64
# Labor Freedom                  186 non-null float64
# Monetary Freedom               186 non-null float64
# Trade Freedom                  186 non-null float64
# ...
