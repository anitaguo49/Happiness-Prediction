# %%
import pandas as pd
import qgrid
import matplotlib as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel('efi2019.xlsx')

# %%
data
# Out:
#        CountryName  2019Score  PropertyRights  JudicalEffectiveness  \
# 0    Liechtenstein        NaN             NaN                   NaN
# 1             Iraq        NaN            37.0                  12.3
# 2            Yemen        NaN            19.6                  22.2
# 3            Syria        NaN            37.0                  24.4
# 4          Somalia        NaN            33.7                  26.6
# ..             ...        ...             ...                   ...
# 181      Australia       80.9            79.1                  86.5
# 182    Switzerland       81.9            85.3                  82.0
# 183    New Zealand       84.4            95.0                  83.5
# 184      Singapore       89.4            97.4                  92.4
# 185      Hong Kong       90.2            93.3                  75.3
#
#      GovernmentIntegrity  TaxBurden  GovtSpending  FiscalHealth  \
# 0                    NaN        NaN           NaN           NaN
# ...

# %%
data.info()
# # # data.shape
# data.keys()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 25 columns):
# CountryName                186 non-null object
# 2019Score                  180 non-null float64
# PropertyRights             185 non-null float64
# JudicalEffectiveness       185 non-null float64
# GovernmentIntegrity        185 non-null float64
# TaxBurden                  180 non-null float64
# GovtSpending               183 non-null float64
# FiscalHealth               183 non-null float64
# BusinessFreedom            185 non-null float64
# LaborFreedom               184 non-null float64
# MonetaryFreedom            184 non-null float64
# TradeFreedom               182 non-null float64
# InvestmentFreedom          184 non-null float64
# FinancialFreedom           181 non-null float64
# TariffRateprc              182 non-null float64
# IncomeTaxRateprc           183 non-null float64
# CorporateTaxRateprc        183 non-null float64
# ...

# %%
data.fillna(0, inplace=True)

# %%
data
# Out:
#        CountryName  2019Score  PropertyRights  JudicalEffectiveness  \
# 0    Liechtenstein        0.0             0.0                   0.0
# 1             Iraq        0.0            37.0                  12.3
# 2            Yemen        0.0            19.6                  22.2
# 3            Syria        0.0            37.0                  24.4
# 4          Somalia        0.0            33.7                  26.6
# ..             ...        ...             ...                   ...
# 181      Australia       80.9            79.1                  86.5
# 182    Switzerland       81.9            85.3                  82.0
# 183    New Zealand       84.4            95.0                  83.5
# 184      Singapore       89.4            97.4                  92.4
# 185      Hong Kong       90.2            93.3                  75.3
#
#      GovernmentIntegrity  TaxBurden  GovtSpending  FiscalHealth  \
# 0                    0.0        0.0           0.0           0.0
# ...

# %%
# data['GDP (Billions PPP)'].astype('float32')
# GDP per Capita (PPP)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 25 columns):
# CountryName                186 non-null object
# 2019Score                  186 non-null float64
# PropertyRights             186 non-null float64
# JudicalEffectiveness       186 non-null float64
# GovernmentIntegrity        186 non-null float64
# TaxBurden                  186 non-null float64
# GovtSpending               186 non-null float64
# FiscalHealth               186 non-null float64
# BusinessFreedom            186 non-null float64
# LaborFreedom               186 non-null float64
# MonetaryFreedom            186 non-null float64
# TradeFreedom               186 non-null float64
# InvestmentFreedom          186 non-null float64
# FinancialFreedom           186 non-null float64
# TariffRateprc              186 non-null float64
# IncomeTaxRateprc           186 non-null float64
# CorporateTaxRateprc        186 non-null float64
# ...
